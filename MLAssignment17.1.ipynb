# %% [markdown]
# ### 1.	What are the three stages to build the hypotheses or model in machine learning?

# %% [markdown]
# Below are the three stages of Model Building
#
# 1)	Model building
#
# 2)	Model testing
#
# 3)	Deployment of model

# %% [markdown]
# ### 2.	What is the standard approach to supervised learning?

# %% [markdown]
# The standard approach to supervised learning is to identify dependent and independed variable and split the data into Training and Test Data. Training the data on Train data set and making the prediction based on test dataset and evaluate based on the cost function.

# %% [markdown]
# ### 3.	What is Training set and Test set?

# %% [markdown]
# Training Set: Training Dataset is something which is used to feed or learn the model to unfold the hidden relationship and patterns
#
# Test Set: Test set is used to test the accuracy of the hypotheses generated by the classifier.

# %% [markdown]
# ### 4.	What is the general principle of an ensemble method and what is bagging and boosting in ensemble method?

# %% [markdown]
# The general principle of an ensemble method is to combine the predictions of several models built with a given learning algorithm in order to improve robustness over a single model.
# Bagging is a method in ensemble for improving unstable estimation or classification schemes.
# Boosting is a method used sequentially to reduce the bias of the combined model. Boosting can reduce errors by reducing the variance term.

# %% [markdown]
# ### 5.	How can you avoid overfitting?

# %% [markdown]
# Steps for reducing overfitting:
# a.	Add more data
# b.	Use data augmentation
# c.	Use architectures that generalize well
# d.	Add regularization (mostly dropout, L1/L2 regularization are also possible)
# e.	Reduce architecture complexity.
